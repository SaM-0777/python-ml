# %% [markdown]
# <a href="https://colab.research.google.com/github/SaM-0777/python-ml/blob/main/Plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sbn

# %%
df = sbn.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sbn.heatmap(df.corr())

# %% [markdown]
# ## Jointplot

# %%
sbn.jointplot(x='tip', y='total_bill', data=df, kind='hex')

# %%
sbn.jointplot(x='tip', y='total_bill', data=df, kind='reg')   ### draws a regression line (probability density function)

# %% [markdown]
# ## Pairplot

# %%
sbn.pairplot(df)

# %%
sbn.distplot(df['tip'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Categorial Plot

# %% [markdown]
# ### Countplot

# %%
sbn.countplot('tip', data=df)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sbn.countplot(x='total_bill', data=df)

# %%
sbn.countplot(x='smoker', data=df)

# %% [markdown]
# ### Barplot

# %%
sbn.barplot(y='total_bill', x='sex', data=df)

# %% [markdown]
# ### Boxplot

# %%
sbn.boxplot(x='sex', y='total_bill', data=df)

# %%
sbn.boxplot(data=df, orient='v')

# %%
sbn.boxplot(x='total_bill', y='time', hue='time', data=df)

# %% [markdown]
# ### Violinplot

# %%
sbn.violinplot(x='total_bill', y='day', data=df, palette='rainbow')
